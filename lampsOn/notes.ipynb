# %% [markdown]
# 램프의 행 상태는 종류가 한정적일 수 밖에 없다.  그리고 종류가 다른 행을 동시에 키는 방법도 없다.
# 그래서 나는, 존재하는 모든 행의 상태를 기록하고, 최대 행 부터 시작해서 각 상태를 모두 킬 수 있는지 확인해보려 한다. 누르는 횟수가 초과분인 경우는 짝수번 남으면 가능, 아님 탈락.
# 그리하여 킬 수 있는 경우의 수를 알아보는 방법으로 해보자.
