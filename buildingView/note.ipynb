# %% [markdown]
# 전혀 느낌이 안오지만, 머릿속에서 시나리오를 굴려보니 아래로 볼록인게 중요한거 같다.
# 경사에 근거하여 연속적인 볼록 여부를 나눠보도록 하자.

# %% [markdown]
# 위 방법에는 빵꾸가 있다.
# 오목/볼록의 여부로는 절대적인 높이 차이를 고려할 수 없고, 그렇게 되면 오목 / 볼록 구간이더라도 절대적으로 건물이 높게 솟아서, 건물 몇개를 간격을 두고 보이는 현상은 포합하지 못한다.
# 절대적인 높이도 고려해야하는 동적 프로그래밍이 필요한걸까.
# 심사숙고 끝에 n^2 복잡도의 브루탈 도입해보기로 함.
